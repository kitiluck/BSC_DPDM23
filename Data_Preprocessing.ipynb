# %% [markdown]
# <a href="https://colab.research.google.com/github/kitiluck/BSC_DPDM23/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/BSC_DPDM2023/customer_shopping_data.csv')
shopping_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %%
shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
#  ## เราจะลบ Price ของ recods ที่เป็น Clothing Cash, Metrociity ออก เพื่อจำลอง Missing Data

# %% [markdown]
# ตรวจสอบค่าก่อน missing

# %%
shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')]
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# ...

# %%
shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')].describe()
# Out:
#                age     quantity        price
# count  2284.000000  2284.000000  2284.000000
# mean     43.657618     2.982049   894.853275
# std      14.974270     1.408979   422.806539
# min      18.000000     1.000000   300.080000
# 25%      30.750000     2.000000   600.160000
# 50%      44.000000     3.000000   900.240000
# 75%      57.000000     4.000000  1200.320000
# max      69.000000     5.000000  1500.400000

# %%
import numpy as np

# %% [markdown]
# ทำให้ price missing

# %%
willbemissing = shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')]

# %%
willbemissing['price'] = np.nan
# Out:
# <ipython-input-9-cb08903f3628>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   willbemissing['price'] = np.nan

# %%
willbemissing
# Out:
#       invoice_no customer_id  gender  age  category  quantity  price  \
# 2        I127801     C266599    Male   20  Clothing         1    NaN
# 382      I591015     C286181  Female   69  Clothing         1    NaN
# 446      I423124     C109593  Female   66  Clothing         1    NaN
# 531      I223795     C280596    Male   40  Clothing         3    NaN
# 647      I891465     C175833  Female   19  Clothing         1    NaN
# ...          ...         ...     ...  ...       ...       ...    ...
# 98987    I693615     C323954  Female   33  Clothing         2    NaN
# 99153    I922072     C336171    Male   47  Clothing         4    NaN
# 99178    I135939     C211085    Male   40  Clothing         3    NaN
# 99339    I287566     C216529  Female   48  Clothing         1    NaN
# 99390    I283542     C780439    Male   35  Clothing         1    NaN
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# ...

# %% [markdown]
# แยก data ส่วนที่ไม่ missing ออกมา

# %%
nomissing = shopping_data[(shopping_data['category']!='Clothing') |
              (shopping_data['payment_method']!='Cash') |
              (shopping_data['shopping_mall']!='Metrocity')]

# %% [markdown]
# จับมันกลับมารวมกัน

# %%
new_shopping_data  = pd.concat([willbemissing,nomissing])
new_shopping_data.shape
# Out:
# (99457, 10)

# %% [markdown]
# ## Example

# %%
new_shopping_data

# %%
new_shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price              True
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# ## Fix

# %% [markdown]
# ### ignore (ลบออกไปเลย)

# %% [markdown]
# Quiz
#
#  - data หายไปกี่ %
#  - mean data รวมหลังจากแก้ missing เป็นเท่าไหร่

# %%
new_shopping_data_drop = new_shopping_data.dropna()

# %%
100*((len(new_shopping_data)-len(new_shopping_data_drop))/len(new_shopping_data))
# Out:
# 2.2964698311833254

# %%
new_shopping_data_drop.describe()
# Out:
#                 age      quantity         price
# count  97173.000000  97173.000000  97173.000000
# mean      43.421671      3.003931    684.423873
# std       14.990459      1.413123    949.438067
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     40.660000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ### 2. เติมด้วย unknown* เราจะเติมกับข้อมูล categorical

# %% [markdown]
# ### 3. เติมด้วยค่าเฉลี่ย

# %% [markdown]
# Quiz
#
#   - mean ใหม่จะเป็นเท่าไหร่

# %%
mean_val = new_shopping_data_drop['price'].mean()

# %%
new_shopping_data_drop['price'].mean()
# Out:
# 684.4238731952291

# %%
new_shopping_data_fillmean = new_shopping_data.fillna({'price':mean_val})
new_shopping_data_fillmean['price'].mean()
# Out:
# 684.423873195229

# %%
new_shopping_data_fillmean.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    684.423873
# std       14.990054      1.413025    938.472859
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ### 4. เติมด้วยค่าเฉลี่ยของกลุ่ม

# %% [markdown]
# Quiz
#
#   - mean หลังเติมด้วยค่าเฉลี่ย Clothing
#   - mean หลังเติมด้วยค่าเฉลี่ย Cash
#   - mean หลังเติมด้วยค่าเฉลี่ย Metrocity
#   - mean หลังเติมด้วยค่าเฉลี่ย Cash+Metrocity

# %%
new_shopping_data[new_shopping_data['category']=='Clothing']['price'].mean()
# Out:
# 901.5259373350307

# %%
new_shopping_data_fillcloth = new_shopping_data.fillna({'price':new_shopping_data[new_shopping_data['category']=='Clothing']['price'].mean()})
new_shopping_data_fillcloth.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.409557
# std       14.990054      1.413025    939.036135
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
new_shopping_data_fillcash = new_shopping_data.fillna(
    {'price':new_shopping_data[new_shopping_data['payment_method']=='Cash']['price'].mean()})
new_shopping_data_fillcash.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    684.317022
# std       14.990054      1.413025    938.473117
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
new_shopping_data_fillmega = new_shopping_data.fillna(
    {'price':new_shopping_data[new_shopping_data['shopping_mall']=='Metrocity']['price'].mean()})
new_shopping_data_fillmega.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    683.513500
# std       14.990054      1.413025    938.491645
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
new_shopping_data_fillmegacash = new_shopping_data.fillna(
    {'price':new_shopping_data[(new_shopping_data['shopping_mall']=='Metrocity') &
                               (new_shopping_data['payment_method']=='Cash')]['price'].mean()})
new_shopping_data_fillmegacash.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    681.979032
# std       14.990054      1.413025    938.608338
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %%
willbedup = shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')]

# %%
new_shopping_dup = pd.concat([shopping_data,willbedup])

# %%
new_shopping_dup.shape
# Out:
# (101741, 10)

# %%
new_shopping_dup
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 0        I138884     C241288  Female   28  Clothing         5  1500.40
# 1        I317333     C111565    Male   21     Shoes         3  1800.51
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 3        I173702     C988172  Female   66     Shoes         5  3000.85
# 4        I337046     C189076  Female   53     Books         4    60.60
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date   shopping_mall
# 0        Credit Card     5/8/2022          Kanyon
# ...

# %%
new_shopping_dup =new_shopping_dup.sort_values(by='invoice_date')

# %% [markdown]
# ## Example

# %%
new_shopping_dup.duplicated()
# Out:
# 41431    False
# 13715    False
# 36955    False
# 67503    False
# 94539    False
#          ...
# 57595    False
# 48891    False
# 95968    False
# 54569    False
# 94163    False
# Length: 101741, dtype: bool

# %%
new_shopping_dup.duplicated().any()
# Out:
# True

# %%
new_shopping_dup[new_shopping_dup.duplicated()]
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 30645    I235671     C196703  Female   45  Clothing         2   600.16
# 27812    I836951     C382440    Male   54  Clothing         3   900.24
# 67018    I122424     C970402  Female   30  Clothing         1   300.08
# 52134    I740632     C283467  Female   49  Clothing         5  1500.40
# 32519    I341543     C754279  Female   53  Clothing         5  1500.40
# ...          ...         ...     ...  ...       ...       ...      ...
# 82563    I301995     C734886  Female   67  Clothing         2   600.16
# 63360    I180399     C286433  Female   31  Clothing         3   900.24
# 90298    I422962     C183016  Female   55  Clothing         2   600.16
# 97787    I275007     C259969    Male   61  Clothing         2   600.16
# 86164    I473988     C714996  Female   45  Clothing         4  1200.32
#
#       payment_method invoice_date shopping_mall
# 30645           Cash     1/1/2021     Metrocity
# ...

# %% [markdown]
# ## Fix

# %%
new_shopping_dup.drop_duplicates()
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 41431    I880831     C362018    Male   47      Books         2    30.30
# 13715    I151379     C733582    Male   45   Clothing         1   300.08
# 36955    I966320     C169558  Female   59   Clothing         3   900.24
# 67503    I983410     C118410    Male   61       Toys         4   143.36
# 94539    I234686     C866358  Female   29  Cosmetics         2    81.32
# ...          ...         ...     ...  ...        ...       ...      ...
# 57595    I682579     C505081  Female   67  Cosmetics         4   162.64
# 48891    I208010     C261419  Female   23      Shoes         5  3000.85
# 95968    I328329     C294627    Male   21   Clothing         1   300.08
# 54569    I100441     C202089  Female   43  Cosmetics         3   121.98
# 94163    I172339     C298256  Female   33   Clothing         5  1500.40
#
#       payment_method invoice_date      shopping_mall
# ...

# %%
new_shopping_dup.drop_duplicates().duplicated().any()
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Example

# %%
plt.boxplot(shopping_data['price']);

# %% [markdown]
# ## Fix

# %%
ret = plt.boxplot(shopping_data['price'])

# %%
ret
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f201ef498d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f201ef4b550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f201ef4ae90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f201f0d24a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f201f0d03d0>],
#  'means': []}

# %%
ret['whiskers'][0].get_ydata()
# Out:
# array([45.45,  5.23])

# %%
ret['whiskers'][1].get_ydata()
# Out:
# array([1200.32, 2400.68])

# %%
ret['whiskers'][1].get_ydata()[1]
# Out:
# 2400.68

# %%
shopping_data[shopping_data['price']<=ret['whiskers'][1].get_ydata()[1]]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 4        I337046     C189076  Female   53            Books         4    60.60
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# ...          ...         ...     ...  ...              ...       ...      ...
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %% [markdown]
# ## Example

# %%
shopping_data.sort_values(by='age')
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 69089    I907811     C167489    Male   18     Shoes         3  1800.51
# 95060    I128262     C687788    Male   18      Toys         4   143.36
# 78728    I280590     C142284  Female   18  Clothing         2   600.16
# 55784    I210628     C525437  Female   18     Books         2    30.30
# 2443     I115916     C338582    Male   18     Shoes         5  3000.85
# ...          ...         ...     ...  ...       ...       ...      ...
# 66267    I433176     C202678    Male   69      Toys         5   179.20
# 66279    I213234     C176169  Female   69     Shoes         2  1200.34
# 85428    I117055     C208685  Female   69  Souvenir         2    23.46
# 66133    I288825     C345511  Female   69  Clothing         1   300.08
# 62421    I366654     C302779  Female   69  Clothing         5  1500.40
#
#       payment_method invoice_date     shopping_mall
# 69089     Debit Card    12/9/2022            Kanyon
# ...

# %% [markdown]
# แก้ค่า age ของ invoice_no = [I280590,I210628] เป็น less than 18

# %%
shopping_data[(shopping_data['invoice_no']=='I280590') | (shopping_data['invoice_no']=='I210628')]['age'] = 'less than 18'
# Out:
# <ipython-input-89-2bc379db66ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shopping_data[(shopping_data['invoice_no']=='I280590') | (shopping_data['invoice_no']=='I210628')]['age'] = 'less than 18'

# %%
shopping_data.loc[55784,'age'] = 'less than 18'
shopping_data.loc[78728,'age'] = 'less than 18'

# %%
shopping_data[(shopping_data['invoice_no']=='I280590') | (shopping_data['invoice_no']=='I210628')]
# Out:
#       invoice_no customer_id  gender           age  category  quantity  \
# 55784    I210628     C525437  Female  less than 18     Books         2
# 78728    I280590     C142284  Female  less than 18  Clothing         2
#
#         price payment_method invoice_date   shopping_mall
# 55784   30.30           Cash   30/09/2022  Forum Istanbul
# 78728  600.16     Debit Card   26/10/2022  Forum Istanbul

# %% [markdown]
# ค่อยมาพิมตรงนี้ 1 โค้ด

# %% [markdown]
# ## Fix

# %% [markdown]
# ## ทดลองประมวลผล column age

# %%
shopping_data.describe()
# Out:
#            quantity         price
# count  99457.000000  99457.000000
# mean       3.003429    689.256321
# std        1.413025    941.184567
# min        1.000000      5.230000
# 25%        2.000000     45.450000
# 50%        3.000000    203.300000
# 75%        4.000000   1200.320000
# max        5.000000   5250.000000

# %% [markdown]
# ## สมมติว่า error บอกว่าไม่สามารถประมวลผลค่า 'less than 18' ได้

# %% [markdown]
# ## หาค่าที่ทำให้ error อยู่ที่ไหน

# %%
shopping_data[shopping_data.eq('less than 18').any(1)]
# Out:
# <ipython-input-93-4744250e9fad>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   shopping_data[shopping_data.eq('less than 18').any(1)]
#       invoice_no customer_id  gender           age  category  quantity  \
# 55784    I210628     C525437  Female  less than 18     Books         2
# 78728    I280590     C142284  Female  less than 18  Clothing         2
#
#         price payment_method invoice_date   shopping_mall
# 55784   30.30           Cash   30/09/2022  Forum Istanbul
# 78728  600.16     Debit Card   26/10/2022  Forum Istanbul

# %% [markdown]
# ## แทนด้วยค่าที่เหมาะสม

# %%
shopping_data['age'] = shopping_data['age'].replace('less than 18',17)

# %%
shopping_data[(shopping_data['invoice_no']=='I280590') | (shopping_data['invoice_no']=='I210628')]
# Out:
#       invoice_no customer_id  gender  age  category  quantity   price  \
# 55784    I210628     C525437  Female   17     Books         2   30.30
# 78728    I280590     C142284  Female   17  Clothing         2  600.16
#
#       payment_method invoice_date   shopping_mall
# 55784           Cash   30/09/2022  Forum Istanbul
# 78728     Debit Card   26/10/2022  Forum Istanbul

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example
#
# เกิดเมื่อรวมข้อมูลจจากหลายแหล่งแล้ว ค่าใน 2 columns
# ไม่เป็นไปในทางเดียวกัน เช่น column อายุ ไม่ตรงกับ column วันเกิดหลังจากคำนวณอายุแล้ว

# %% [markdown]
# ## Fix

# %% [markdown]
# เลือกเก็บไว้เฉพาะ column ที่ถูก

# %% [markdown]
# # Data Integration (การรวมข้อมูลจากหลายแหล่ง)

# %%
sep_df = pd.read_excel ('/content/drive/MyDrive/DataViz23Data/-30.09.65.xlsx', header=8, skipfooter=26)
sep_df = sep_df.iloc[-2:,:15]
sep_df['เดือน-ปี'] = len(sep_df)*['sep-65']
sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2            -3.239918e+07            NaN             NaN   sep-65
# 3             1.563013e+07            6.0            15.0   sep-65

# %%
oct_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/untitled.xlsx', header=9, skipfooter=27)
oct_df = oct_df.iloc[-2:,:15]
oct_df['เดือน-ปี'] = len(oct_df)*['oct-65']
oct_df
# Out:
#   รายการ     งบประมาณ  สำรองเงินมีหนี้          PO     เบิกจ่าย  \
# 2  ประจำ  6822.811789              NaN   12.706842  3984.779058
# 3  ลงทุน  6180.211723              NaN  457.295806  1291.209026
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q1  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         58.403766           35.0     23.403766               3997.485900
# 3         20.892634           19.0      1.892634               1748.504832
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q1.1  */- เป้าหมาย.1  \
# 2           58.590007            35.33       23.260007
# 3           28.291989            28.96       -0.668011
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2              2825.325889            NaN             NaN   oct-65
# 3              4431.706890            4.0             6.0   oct-65

# %% [markdown]
# ## 1. รวมแกน X (เพิ่ม columns - เพิ่ม feature)

# %%
sep_oct_df = pd.concat([sep_df,oct_df])
sep_oct_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
# 2  ประจำ  6.822812e+03              NaN  1.270684e+01  3.984779e+03
# 3  ลงทุน  6.180212e+03              NaN  4.572958e+02  1.291209e+03
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
# 2         58.403766            NaN     23.403766              3.997486e+03
# 3         20.892634            NaN      1.892634              1.748505e+03
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
# 2           58.590007              NaN       23.260007
# ...

# %% [markdown]
# ## 2. รวมแกน Y (เพิ่ม row - เพิ่ม data)

# %%
project_df = pd.read_csv ('/content/drive/MyDrive/DataViz23Data/opendata_project-2.csv')
project_df.head()
# Out:
#    row_number                project_id                     name_en  \
# 0     20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1      4268.0             project_15905              Liberty Park 2
# 2      5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3     21762.0              project_6010              Baan Thara Rin
# 4     10751.0             project_11312             The Forest Hill
#
#                       name_th propertytype_id propertytype_name_en  \
# 0  บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 1          ลิเบอร์ตี้ พาร์ค 2               2                Condo
# 2    พลีโน่ พหลโยธิน-สายไหม 2               3             Townhome
# 3              บ้านธารารินทร์               1       Detached House
# 4          เดอะ ฟอเรสต์ ฮิลล์               1       Detached House
#
#   propertytype_name_th  price_min     developer_id  \
# 0             ทาวน์โฮม  1490000.0   developer_7326
# ...

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/DataViz23Data/opendata_unittype-2.csv')
unit_df.head()
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# ...

# %% [markdown]
# ค่อยมาพิมต่อ

# %%
project_df = project_df.drop_duplicates(subset='project_id')

# %%
unit_df['province_en'] = unit_df['project_id'].map(project_df.set_index('project_id')['province_name_en'])

# %%
project_df = project_df.drop_duplicates(subset='project_id',keep='last')

# %%
unit_df
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 2           12994            unittype_37624             project_16674
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# ...

# %% [markdown]
# # Data Reduction

# %% [markdown]
# ## Reduce number of data (Y-axis) - Sampling

# %%
shopping_data.sample(random_state=6)
# Out:
#       invoice_no customer_id  gender  age  category  quantity  price  \
# 81034    I209459     C312307  Female   18  Souvenir         1  11.73
#
#       payment_method invoice_date shopping_mall
# 81034           Cash   13/05/2021   Cevahir AVM

# %%
shopping_data.sample(n=10, random_state=6)
# Out:
#       invoice_no customer_id  gender  age         category  quantity   price  \
# 81034    I209459     C312307  Female   18         Souvenir         1   11.73
# 91838    I351059     C292856    Male   41         Clothing         2  600.16
# 20458    I323617     C325754  Female   24         Clothing         2  600.16
# 73343    I104653     C209092    Male   62             Toys         5  179.20
# 70406    I804767     C196027  Female   65         Clothing         3  900.24
# 65247    I137393     C726791  Female   37  Food & Beverage         3   15.69
# 49419    I650563     C283975    Male   28         Clothing         3  900.24
# 90371    I109001     C901685  Female   36             Toys         3  107.52
# 98492    I394097     C307872    Male   29  Food & Beverage         1    5.23
# 11309    I163506     C223150    Male   34  Food & Beverage         1    5.23
#
#       payment_method invoice_date     shopping_mall
# 81034           Cash   13/05/2021       Cevahir AVM
# ...

# %%
shopping_data.sample(frac=0.2, random_state=6)
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 81034    I209459     C312307  Female   18  Souvenir         1    11.73
# 91838    I351059     C292856    Male   41  Clothing         2   600.16
# 20458    I323617     C325754  Female   24  Clothing         2   600.16
# 73343    I104653     C209092    Male   62      Toys         5   179.20
# 70406    I804767     C196027  Female   65  Clothing         3   900.24
# ...          ...         ...     ...  ...       ...       ...      ...
# 75991    I189802     C338933  Female   63  Clothing         3   900.24
# 85083    I121218     C125359    Male   42  Clothing         3   900.24
# 55086    I365478     C904439  Female   62  Clothing         4  1200.32
# 1096     I145120     C293612  Female   60  Clothing         4  1200.32
# 53171    I314401     C329300    Male   31  Clothing         3   900.24
#
#       payment_method invoice_date     shopping_mall
# 81034           Cash   13/05/2021       Cevahir AVM
# ...

# %%
sam_no_replace = shopping_data.sample(frac=0.2, random_state=6)
sam_no_replace.duplicated().any()
# Out:
# False

# %%
sam_with_replace = shopping_data.sample(frac=0.2, replace=True, random_state=6)
sam_with_replace.duplicated().any()
# Out:
# True

# %%
sam_with_replace_120 = shopping_data.sample(frac=1.2, replace=True, random_state=6)

# %%
sam_with_replace_120.shape
# Out:
# (119348, 10)

# %% [markdown]
# ## Reduce dimension of data (X-axis) - PCA & Stats
